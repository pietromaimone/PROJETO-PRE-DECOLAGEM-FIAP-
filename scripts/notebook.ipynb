# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# 🚀 Sistema de Verificação de Decolagem e Análise Energética\n",
        "\n",
        "Este notebook executa e analisa os cenários de decolagem a partir do arquivo `banco_de_dados_real.csv`."
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "## 1. Importação dos Módulos\n",
        "Carregamos as funções de verificação física, processamento dos dados do CSV e cálculo de autonomia energética."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "from verificacao import verificar_decolagem\n",
        "from analise_energetica import calcular_autonomia, exibir_analise_cenario\n",
        "from processar_csv import ler_cenarios, avaliar_cenario, imprimir_relatorio, buscar_cenario\n",
        "\n",
        "CSV_PATH = 'banco_de_dados_real.csv'\n",
        "print(f'Arquivo configurado: {CSV_PATH}')"
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "## 2. Processamento e Avaliação de Todos os Cenários\n",
        "Leitura do banco completo e impressão do relatório com taxa de acerto frente ao gabarito de controle."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "cenarios = ler_cenarios(CSV_PATH)\n",
        "resultados = [avaliar_cenario(c) for c in cenarios]\n",
        "\n",
        "# Exibe a tabela e os totais\n",
        "imprimir_relatorio(resultados)"
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "## 3. Análise Energética Detalhada por Cenário Específico\n",
        "Selecione um número de cenário para inspecionar os parâmetros e o cálculo automático de autonomia pós-decolagem."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# Escolha o número do cenário (ex: '7', '1', etc.)\n",
        "numero_cenario = '7'\n",
        "\n",
        "cenario = buscar_cenario(cenarios, numero_cenario)\n",
        "\n",
        "if cenario is None:\n",
        "    print(f'Cenário cenario_{numero_cenario} não existe no CSV.')\n",
        "else:\n",
        "    res = avaliar_cenario(cenario)\n",
        "    if res['pode_decolar']:\n",
        "        exibir_analise_cenario(cenario, res)\n",
        "    else:\n",
        "        print(f\"\\nA nave do cenário {cenario['id']} NÃO está pronta para decolagem!\")\n",
        "        print(f\"Motivo: {res['motivo']}\")"
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "## 4. Análise Tabular com Pandas\n",
        "Visualização das primeiras linhas da análise em formato DataFrame."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import pandas as pd\n",
        "\n",
        "df = pd.DataFrame(resultados)\n",
        "display(df.head(10))\n",
        "\n",
        "taxa_liberados = (df['pode_decolar'].sum() / len(df)) * 100\n",
        "print(f'Taxa de decolagens autorizadas: {taxa_liberados:.1f}%')"
      ]
    }
  ],
  "metadata": {
    "language_info": {
      "name": "python",
      "version": "3"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
